# %% [markdown]
# ## **Movie Recommendation System - TMDb dataset**

# %% [markdown]
# ### **1.IMPORTING LIBRARIES**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# here's several helpful packages to load
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import warnings
warnings.filterwarnings('ignore')

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ### **2.LOAD DATA**

# %%
# Download TMDB movie data
movie = '/content/drive/MyDrive/Kaggle_Datasets/Machine Learning /Recommendation Systems/tmdb_5000_movies.csv'
credit = '/content/drive/MyDrive/Kaggle_Datasets/Machine Learning /Recommendation Systems/tmdb_5000_credits.csv'

movies = pd.read_csv(movie)
credits = pd.read_csv(credit)

movies.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
print(movies.shape)
print(movies.info())
# Out:
# (4803, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
# ...

# %%
credits.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 4 columns]

# %%
print(credits.shape)
print(credits.info())
# Out:
# (4803, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB
# None

# %%
# Merging both Movies & Credits dataframes on the basis of title
df = movies.merge(credits,on='title')
df.head()
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
print(df.shape)
# Out:
# (4809, 23)

# %% [markdown]
# ### **3.FEATURE ENGINEERING**

# %% [markdown]
# ##### we will remove unnecessary features from the dataset
#
# #### **important features ->**
#
# * budget
# * homepage
# * id
# * original_language
# * original_title
# * popularity
# * production_comapny
# * production_countries
# * release-date(not sure)

# %%
# important features -> genres, id, keywords, title, overview, cast, crew
df = df[['movie_id','title','overview','genres','keywords','cast','crew']]
df.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 7 columns]

# %% [markdown]
# #### **Creating Tags**

# %%
df.isna().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
# 3 null values in overview column is a very small number so we'll drop them
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
# Checking duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
import ast

def get_genres(text):
    lst = []
    for i in ast.literal_eval(text):
        lst.append(i['name'])
    return lst

# %%
df['genres'] = df['genres'].apply(get_genres)
df.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 7 columns]

# %%
def get_keys(text):
    lst = []
    for i in ast.literal_eval(text):
        lst.append(i['name'])
    return lst

# %%
df['keywords'] = df['keywords'].apply(get_keys)
df.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 7 columns]

# %%
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
def get_cast(text):
    lst = []
    for i in ast.literal_eval(text):
        lst.append(i['name'])
    return lst

# %%
df['cast'] = df['cast'].apply(get_cast)
df.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 7 columns]

# %%
# Out of all cast we select top 3
df['cast'] = df['cast'].apply(lambda x:x[:3])

# %%
df['cast'][0]
# Out:
# ['Sam Worthington', 'Zoe Saldana', 'Sigourney Weaver']

# %%
def fetch_director(text):
    lst = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            lst.append(i['name'])
    return lst

# %%
df['crew'] = df['crew'].apply(fetch_director)
df.head()
# Out:
#    movie_id  ...                 crew
# 0     19995  ...      [James Cameron]
# 1       285  ...     [Gore Verbinski]
# 2    206647  ...         [Sam Mendes]
# 3     49026  ...  [Christopher Nolan]
# 4     49529  ...     [Andrew Stanton]
#
# [5 rows x 7 columns]

# %%
def collapse(lt):
    lst = []
    for i in lt:
        lst.append(i.replace(" ",""))
    return lst

# %%
# Now we will remove spaces from the features below
cols = df.iloc[:,3:].columns
cols
# Out:
# Index(['genres', 'keywords', 'cast', 'crew'], dtype='object')

# %%
for i in cols:
    df[i] = df[i].apply(collapse)
df.sample(5)
# Out:
#       movie_id  ...                       crew
# 4170     49020  ...            [RichardAyoade]
# 4013       872  ...  [StanleyDonen, GeneKelly]
# 1038     20533  ...             [JimmyHayward]
# 2067      4566  ...               [TonyGilroy]
# 2000     10316  ...            [GeorgeClooney]
#
# [5 rows x 7 columns]

# %%
# overview is a column of string, so we'll covert it into list
df['overview'] = df['overview'].apply(lambda x:x.split())

# %%
# now dataset is ready to make tags
df['tags'] = df['overview'] + df['genres'] + df['keywords'] + df['cast'] + df['crew']

# %%
# now there is no need of overview, keywords, genre, cast, crew
new = df.drop(columns=['overview','genres','keywords','cast','crew'])
new.head()
# Out:
#    movie_id  ...                                               tags
# 0     19995  ...  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1       285  ...  [Captain, Barbossa,, long, believed, to, be, d...
# 2    206647  ...  [A, cryptic, message, from, Bond’s, past, send...
# 3     49026  ...  [Following, the, death, of, District, Attorney...
# 4     49529  ...  [John, Carter, is, a, war-weary,, former, mili...
#
# [5 rows x 3 columns]

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))

# %%
new.head()
# Out:
#    movie_id  ...                                               tags
# 0     19995  ...  In the 22nd century, a paraplegic Marine is di...
# 1       285  ...  Captain Barbossa, long believed to be dead, ha...
# 2    206647  ...  A cryptic message from Bond’s past sends him o...
# 3     49026  ...  Following the death of District Attorney Harve...
# 4     49529  ...  John Carter is a war-weary, former military ca...
#
# [5 rows x 3 columns]

# %%
new['tags'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d SamWorthington ZoeSaldana SigourneyWeaver JamesCameron'

# %%
# now we'll do text vetorization
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()
vector.shape
# Out:
# (4806, 5000)

# %%
cv.get_feature_names()
# Out:
# ['000',
#  '007',
#  '10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '18th',
#  '19',
#  '1930s',
#  '1940s',
#  '1944',
#  '1950',
#  '1950s',
#  '1960s',
#  '1970s',
#  '1971',
#  '1974',
#  '1976',
#  '1980',
#  '1980s',
#  '1985',
#  '1990s',
#  '1999',
#  '19th',
#  '19thcentury',
#  '20',
#  '200',
#  '2003',
#  '2009',
#  '20th',
#  '24',
#  '25',
#  '30',
#  '300',
#  '3d',
#  '40',
#  '50',
#  '500',
#  '60',
#  '60s',
#  '70',
#  'aaron',
#  'aaroneckhart',
#  'abandoned',
#  'abducted',
#  'abigailbreslin',
#  'abilities',
#  'ability',
#  'able',
#  'aboard',
#  'abuse',
#  'abusive',
#  'academic',
#  'academy',
#  'accept',
#  'accepted',
#  'accepts',
#  'access',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accompanied',
#  'accomplish',
#  'account',
#  'accountant',
#  'accused',
#  'ace',
#  'achieve',
#  'act',
#  'acting',
#  'action',
#  'actionhero',
#  'actions',
#  'activist',
#  'activities',
# ...

# %% [markdown]
# ### **4.MODEL BUILDING**

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vector)
similarity
# Out:
# array([[1.        , 0.08964215, 0.06071767, ..., 0.02519763, 0.0277885 ,
#         0.        ],
#        [0.08964215, 1.        , 0.06350006, ..., 0.02635231, 0.        ,
#         0.        ],
#        [0.06071767, 0.06350006, 1.        , ..., 0.02677398, 0.        ,
#         0.        ],
#        ...,
#        [0.02519763, 0.02635231, 0.02677398, ..., 1.        , 0.07352146,
#         0.04774099],
#        [0.0277885 , 0.        , 0.        , ..., 0.07352146, 1.        ,
#         0.05264981],
#        [0.        , 0.        , 0.        , ..., 0.04774099, 0.05264981,
#         1.        ]])

# %%
print(similarity.shape)
print(similarity[0])
# Out:
# (4806, 4806)
# [1.         0.08964215 0.06071767 ... 0.02519763 0.0277885  0.        ]

# %%
index = new[new['title'] == 'The Lego Movie'].index[0]
index
# Out:
# 744

# %%
sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x:x[1])[1:6]
# Out:
# [(503, 0.29591817714964314),
#  (742, 0.28577380332470415),
#  (934, 0.282842712474619),
#  (368, 0.28),
#  (179, 0.2683281572999748)]

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key=lambda x:x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend('Avatar')
# Out:
# Titan A.E.
# Small Soldiers
# Ender's Game
# Aliens vs Predator: Requiem
# Independence Day

# %%
recommend('Batman')
# Out:
# Batman
# Batman & Robin
# The Dark Knight Rises
# Batman Begins
# Batman Returns

# %% [markdown]
# ### **5.SAVE FILE**

# %%
import pickle

pickle.dump(new,open('movie_list.pkl', 'wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
